# %%
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("long_text.csv", sep=',', engine='python')

# %%
df.head()
# Out:
#        DATE  VALUE                                            COMMENT
# 0  01/01/48    3.4  The first round was held from 19 to 20 March, ...
# 1  01/02/48    3.8  The 2019 Tour Championship was a professional ...
# 2  01/03/48    4.0  The draw for the Tour Championship comprised t...
# 3  01/04/48    3.9  In a repeat of the Players Championship final ...
# 4  01/05/48    3.5  The event featured 22 century breaks made by s...

# %%
df
# Out:
#         DATE  VALUE                                            COMMENT
# 0   01/01/48    3.4  The first round was held from 19 to 20 March, ...
# 1   01/02/48    3.8  The 2019 Tour Championship was a professional ...
# 2   01/03/48    4.0  The draw for the Tour Championship comprised t...
# 3   01/04/48    3.9  In a repeat of the Players Championship final ...
# 4   01/05/48    3.5  The event featured 22 century breaks made by s...
# ..       ...    ...                                                ...
# 85  01/05/51    3.0  Ronnie O'Sullivan played Stuart Bingham in the...
# 86  01/06/51    3.2  The fourth and final first round match was a r...
# 87  01/07/51    3.1  In the second round, which took place on 21 an...
# 88  01/08/51    3.1  Trump took the first frame in the opening sess...
# 89  01/09/51    3.3  O'Sullivan clinched the first two frames of th...
#
# [90 rows x 3 columns]

# %%
df.head(90)
# Out:
#         DATE  VALUE                                            COMMENT
# 0   01/01/48    3.4  The first round was held from 19 to 20 March, ...
# 1   01/02/48    3.8  The 2019 Tour Championship was a professional ...
# 2   01/03/48    4.0  The draw for the Tour Championship comprised t...
# 3   01/04/48    3.9  In a repeat of the Players Championship final ...
# 4   01/05/48    3.5  The event featured 22 century breaks made by s...
# ..       ...    ...                                                ...
# 85  01/05/51    3.0  Ronnie O'Sullivan played Stuart Bingham in the...
# 86  01/06/51    3.2  The fourth and final first round match was a r...
# 87  01/07/51    3.1  In the second round, which took place on 21 an...
# 88  01/08/51    3.1  Trump took the first frame in the opening sess...
# 89  01/09/51    3.3  O'Sullivan clinched the first two frames of th...
#
# [90 rows x 3 columns]

# %%
pd.set_option("display.max_rows", None)
df
# Out:
#         DATE  VALUE                                            COMMENT
# 0   01/01/48    3.4  The first round was held from 19 to 20 March, ...
# 1   01/02/48    3.8  The 2019 Tour Championship was a professional ...
# 2   01/03/48    4.0  The draw for the Tour Championship comprised t...
# 3   01/04/48    3.9  In a repeat of the Players Championship final ...
# 4   01/05/48    3.5  The event featured 22 century breaks made by s...
# 5   01/06/48    3.6  The 2019 Tour Championship was the third and f...
# 6   01/07/48    3.6  The Tour Championship was the first event sinc...
# 7   01/08/48    3.9  The tournament was primarily broadcast by ITV4...
# 8   01/09/48    3.8  Robertson won the first three frames of the se...
# 9   01/10/48    3.7  Reigning Masters champion Judd Trump drew reig...
# 10  01/11/48    3.8  Ronnie O'Sullivan played Stuart Bingham in the...
# 11  01/12/48    4.0  The fourth and final first round match was a r...
# ...

# %%
pd.set_option("display.max_columns", None)
df
# Out:
#         DATE  VALUE                                            COMMENT
# 0   01/01/48    3.4  The first round was held from 19 to 20 March, ...
# 1   01/02/48    3.8  The 2019 Tour Championship was a professional ...
# 2   01/03/48    4.0  The draw for the Tour Championship comprised t...
# 3   01/04/48    3.9  In a repeat of the Players Championship final ...
# 4   01/05/48    3.5  The event featured 22 century breaks made by s...
# 5   01/06/48    3.6  The 2019 Tour Championship was the third and f...
# 6   01/07/48    3.6  The Tour Championship was the first event sinc...
# 7   01/08/48    3.9  The tournament was primarily broadcast by ITV4...
# 8   01/09/48    3.8  Robertson won the first three frames of the se...
# 9   01/10/48    3.7  Reigning Masters champion Judd Trump drew reig...
# 10  01/11/48    3.8  Ronnie O'Sullivan played Stuart Bingham in the...
# 11  01/12/48    4.0  The fourth and final first round match was a r...
# ...

# %%
pd.set_option("display.max_colwidth", -1)
df
# Out:
#         DATE  VALUE  \
# 0   01/01/48  3.4
# 1   01/02/48  3.8
# 2   01/03/48  4.0
# 3   01/04/48  3.9
# 4   01/05/48  3.5
# 5   01/06/48  3.6
# 6   01/07/48  3.6
# 7   01/08/48  3.9
# 8   01/09/48  3.8
# 9   01/10/48  3.7
# 10  01/11/48  3.8
# 11  01/12/48  4.0
# 12  01/01/49  4.3
# 13  01/02/49  4.7
# 14  01/03/49  5.0
# 15  01/04/49  5.3
# 16  01/05/49  6.1
# 17  01/06/49  6.2
# 18  01/07/49  6.7
# 19  01/08/49  6.8
# 20  01/09/49  6.6
# 21  01/10/49  7.9
# 22  01/11/49  6.4
# 23  01/12/49  6.6
# 24  01/01/50  6.5
# 25  01/02/50  6.4
# 26  01/03/50  6.3
# 27  01/04/50  5.8
# 28  01/05/50  5.5
# 29  01/06/50  5.4
# 30  01/07/50  5.0
# 31  01/08/50  4.5
# 32  01/09/50  4.4
# 33  01/10/50  4.2
# 34  01/11/50  4.2
# 35  01/12/50  4.3
# 36  01/01/51  3.7
# 37  01/02/51  3.4
# 38  01/03/51  3.4
# 39  01/04/51  3.1
# 40  01/05/51  3.0
# 41  01/06/51  3.2
# 42  01/07/51  3.1
# 43  01/08/51  3.1
# 44  01/09/51  3.3
# 45  01/01/48  3.4
# 46  01/02/48  3.8
# 47  01/03/48  4.0
# ...
